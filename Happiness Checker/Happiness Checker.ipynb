# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
happinessdata = pd.read_csv('data/happiness.csv')
happinessdata
# Out:
#      Unnamed: 0                   Country  Happiness Rank  Happiness Score  \
# 0             0               Switzerland               1            7.587
# 1             1                   Iceland               2            7.561
# 2             2                   Denmark               3            7.527
# 3             3                    Norway               4            7.522
# 4             4                    Canada               5            7.427
# ..          ...                       ...             ...              ...
# 777         151                    Rwanda             152            3.334
# 778         152                  Tanzania             153            3.231
# 779         153               Afghanistan             154            3.203
# 780         154  Central African Republic             155            3.083
# 781         155               South Sudan             156            2.853
#
# ...

# %%
happinessdata.drop(columns='Unnamed: 0', inplace=True)

# %%
print(happinessdata.head())
print("-" *90)
print("-" *90)
print(f"Shape of the data :{happinessdata.shape}")
print("-" *90)
print("-" *90)
print(happinessdata.info())
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1            7.587                   1.39651
# 1      Iceland               2            7.561                   1.30232
# 2      Denmark               3            7.527                   1.32548
# 3       Norway               4            7.522                   1.45900
# 4       Canada               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity
# 0     0.29678
# 1     0.43630
# ...

# %%
happinessdata.describe()
# Out:
#        Happiness Rank  Happiness Score  Economy (GDP per Capita)      Family  \
# count      782.000000       782.000000                782.000000  782.000000
# mean        78.698210         5.379018                  0.916047    1.078392
# std         45.182384         1.127456                  0.407340    0.329548
# min          1.000000         2.693000                  0.000000    0.000000
# 25%         40.000000         4.509750                  0.606500    0.869363
# 50%         79.000000         5.322000                  0.982205    1.124735
# 75%        118.000000         6.189500                  1.236187    1.327250
# max        158.000000         7.769000                  2.096000    1.644000
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                782.000000  782.000000                     781.000000
# mean                   0.612416    0.411091                       0.125436
# ...

# %%
happinessdata.isnull().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    1
# Generosity                       0
# dtype: int64

# %%
medianhappinessScore = happinessdata['Trust (Government Corruption)'].median()
medianhappinessScore
# Out:
# 0.091

# %%
#happinessdata['Trust (Government Corruption)'].replace(np.nan, medianhappinessScore,inplace=True)

happinessdata['Trust (Government Corruption)'] = happinessdata['Trust (Government Corruption)'].fillna(happinessdata['Trust (Government Corruption)'].median())

# %%
happinessdata.isnull().sum()
# Out:
# Country                          0
# Happiness Rank                   0
# Happiness Score                  0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# dtype: int64

# %%
dup = happinessdata.duplicated()
print(dup.sum())
happinessdata[dup]
# Out:
# 0
# Empty DataFrame
# Columns: [Country, Happiness Rank, Happiness Score, Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity]
# Index: []

# %%
happinessdata.drop_duplicates(inplace=True)

# %% [markdown]
# # Outlier Detection

# %%
happinessdata.boxplot(column=['Happiness Score'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
happinessdata.boxplot(column=['Family'])
plt.show()

	#Happiness Score	Economy (GDP per Capita)	Family	Health (Life Expectancy)	Freedom	Trust (Government Corruption)	Generosity

# %%
happinessdata.boxplot(column=['Generosity'])
plt.show()

# %% [markdown]
# # outlier detection and removal

# %%
def removeoutlier(col):
    sorted(col)
    q1,q3=col.quantile([0.25,0.75])
    IQR=q3-q1
    lowerrange=q1-(1.5 * IQR)
    upperrange = q3 + (1.5 * IQR)
    return lowerrange, upperrange

# %%
lscore, hscore = removeoutlier(happinessdata['Family'])
print(lscore,hscore)
happinessdata['Family']=np.where(happinessdata['Family']>hscore,hscore,happinessdata['Family'])
happinessdata['Family']=np.where(happinessdata['Family']<lscore,lscore,happinessdata['Family'])
# Out:
# 0.18253125000000003 2.0140812500000003

# %%
lscore, hscore = removeoutlier(happinessdata['Generosity'])
print(lscore,hscore)
happinessdata['Generosity']=np.where(happinessdata['Generosity']>hscore,hscore,happinessdata['Generosity'])
happinessdata['Generosity']=np.where(happinessdata['Generosity']<lscore,lscore,happinessdata['Generosity'])
# Out:
# -0.09324874999999996 0.5020812499999999

# %%
happinessdata.boxplot(column=['Generosity'])
plt.show()

# %%
happinessdata
# Out:
#                       Country  Happiness Rank  Happiness Score  \
# 0                 Switzerland               1            7.587
# 1                     Iceland               2            7.561
# 2                     Denmark               3            7.527
# 3                      Norway               4            7.522
# 4                      Canada               5            7.427
# ..                        ...             ...              ...
# 777                    Rwanda             152            3.334
# 778                  Tanzania             153            3.231
# 779               Afghanistan             154            3.203
# 780  Central African Republic             155            3.083
# 781               South Sudan             156            2.853
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# ...

# %% [markdown]
# # Normalizing and Scaling

# %%
from sklearn.preprocessing import StandardScaler
stdscale= StandardScaler()
stdscale
# Out:
# StandardScaler()

# %%
happinessdata['Happiness Score']=stdscale.fit_transform(happinessdata[['Happiness Score']])

# %%
happinessdata.head()
# Out:
#        Country  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0  Switzerland               1         1.959628                   1.39651
# 1      Iceland               2         1.936552                   1.30232
# 2      Denmark               3         1.906377                   1.32548
# 3       Norway               4         1.901939                   1.45900
# 4       Canada               5         1.817625                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity
# 0     0.29678
# 1     0.43630
# ...

# %%
# corelation between different attibutes / features

# %%
temp=happinessdata.drop(columns='Country')

# %%
sns.heatmap(temp.corr(),annot=True,cmap='RdYlGn')
plt.show()

# %% [markdown]
# # Happiness Score – Economy (GDP per Capita) = 0.79
# # Happiness Score – Family = 0.64

# %%
temp
# Out:
#      Happiness Rank  Happiness Score  Economy (GDP per Capita)   Family  \
# 0                 1         1.959628                   1.39651  1.34951
# 1                 2         1.936552                   1.30232  1.40223
# 2                 3         1.906377                   1.32548  1.36058
# 3                 4         1.901939                   1.45900  1.33095
# 4                 5         1.817625                   1.32629  1.32261
# ..              ...              ...                       ...      ...
# 777             152        -1.814994                   0.35900  0.71100
# 778             153        -1.906409                   0.47600  0.88500
# 779             154        -1.931259                   0.35000  0.51700
# 780             155        -2.037761                   0.02600  0.00000
# 781             156        -2.241891                   0.30600  0.57500
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
sns.regplot(x='Economy (GDP per Capita)', y="Happiness Score", data = happinessdata)
plt.show()

# %%
sns.regplot(x='Family', y="Happiness Score", data = happinessdata)
plt.show()

# %%
sns.regplot(x='Health (Life Expectancy)', y="Happiness Score", data = happinessdata)
plt.show()

# %%
sns.regplot(x='Freedom', y="Happiness Score", data = happinessdata)
plt.show()
