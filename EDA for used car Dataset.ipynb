# %% [markdown]
# # Exploratory Data Analysis for used Cars

# %%
import pandas as pd
import numpy as np
import os
# Reading the csv file and storing it in a variable

os.chdir('F:\\DATA SC\\Python notebooks\\old notebooks\\data')
         
os.getcwd()
# Out:
# 'F:\\DATA SC\\Python notebooks\\old notebooks\\data'

# %% [markdown]
# # importing of data set

# %%
data = pd.read_csv("used_cars_data.csv")

# %%
data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0     2010              72000       CNG       Manual      First  26.6 km/kg
# 1     2015              41000    Diesel       Manual      First  19.67 kmpl
# 2     2011              46000    Petrol       Manual      First   18.2 kmpl
# 3     2012              87000    Diesel       Manual      First  20.77 kmpl
# 4     2013              40670    Diesel    Automatic     Second   15.2 kmpl
# ...    ...                ...       ...          ...        ...         ...
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 7248  1598 CC  103.6 bhp    5.0        NaN    NaN
# 7249  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7250  1461 CC   63.1 bhp    5.0        NaN    NaN
# 7251  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7252  2148 CC    170 bhp    5.0        NaN    NaN
#
# [7253 rows x 14 columns]

# %% [markdown]
# # Analyzing the Data - to gain general insights about the data, which covers the number of rows and columns, values in the data, datatypes, and Missing values in the dataset.

# %%
data.shape
# Out:
# (7253, 14)

# %%
data.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# 2   88.7 bhp    5.0  8.61 Lakh   4.50
# 3  88.76 bhp    7.0        NaN   6.00
# 4  140.8 bhp    5.0        NaN  17.74

# %%
data.tail()
# Out:
#       S.No.                                               Name   Location  \
# 7248   7248                  Volkswagen Vento Diesel Trendline  Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI     Mumbai
# 7250   7250                             Nissan Micra Diesel XV    Kolkata
# 7251   7251                             Volkswagen Polo GT TSI       Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...      Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats New_Price  Price
# 7248  1598 CC  103.6 bhp    5.0       NaN    NaN
# 7249  1197 CC  103.6 bhp    5.0       NaN    NaN
# 7250  1461 CC   63.1 bhp    5.0       NaN    NaN
# 7251  1197 CC  103.6 bhp    5.0       NaN    NaN
# 7252  2148 CC    170 bhp    5.0       NaN    NaN

# %% [markdown]
# # Data Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %% [markdown]
# # interpretation of - data.info() shows the variables Mileage, Engine, Power, Seats, New_Price, and Price have missing values. Numeric variables like Mileage, Power are of datatype as  float64 and int64. Categorical variables like Location, Fuel_Type, Transmission, and Owner Type are of object data type

# %% [markdown]
# # Check for Duplication

# %%
data.nunique()
# Out:
# S.No.                7253
# Name                 2041
# Location               11
# Year                   23
# Kilometers_Driven    3660
# Fuel_Type               5
# Transmission            2
# Owner_Type              4
# Mileage               450
# Engine                150
# Power                 386
# Seats                   9
# New_Price             625
# Price                1373
# dtype: int64

# %% [markdown]
# # Missing Values Calculation

# %%
data.isnull().sum()
# Out:
# S.No.                   0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 46
# Power                  46
# Seats                  53
# New_Price            6247
# Price                1234
# dtype: int64

# %% [markdown]
# # percentage of missing values in each column

# %%
(data.isnull().sum()/(len(data)))*100
# Out:
# S.No.                 0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.027575
# Engine                0.634220
# Power                 0.634220
# Seats                 0.730732
# New_Price            86.129877
# Price                17.013650
# dtype: float64

# %% [markdown]
# # interpretation - The percentage of missing values for the columns New_Price and Price is ~86% and ~17%, respectively.

# %% [markdown]
# # Data Reduction

# %%
data
# Out:
#       S.No.                                               Name    Location  \
# 0         0                             Maruti Wagon R LXI CNG      Mumbai
# 1         1                   Hyundai Creta 1.6 CRDi SX Option        Pune
# 2         2                                       Honda Jazz V     Chennai
# 3         3                                  Maruti Ertiga VDI     Chennai
# 4         4                    Audi A4 New 2.0 TDI Multitronic  Coimbatore
# ...     ...                                                ...         ...
# 7248   7248                  Volkswagen Vento Diesel Trendline   Hyderabad
# 7249   7249                             Volkswagen Polo GT TSI      Mumbai
# 7250   7250                             Nissan Micra Diesel XV     Kolkata
# 7251   7251                             Volkswagen Polo GT TSI        Pune
# 7252   7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi
#
#       Year  Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0     2010              72000       CNG       Manual      First  26.6 km/kg
# 1     2015              41000    Diesel       Manual      First  19.67 kmpl
# 2     2011              46000    Petrol       Manual      First   18.2 kmpl
# 3     2012              87000    Diesel       Manual      First  20.77 kmpl
# 4     2013              40670    Diesel    Automatic     Second   15.2 kmpl
# ...    ...                ...       ...          ...        ...         ...
# 7248  2011              89411    Diesel       Manual      First  20.54 kmpl
# 7249  2015              59000    Petrol    Automatic      First  17.21 kmpl
# 7250  2012              28000    Diesel       Manual      First  23.08 kmpl
# 7251  2013              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252  2014              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price  Price
# 0      998 CC  58.16 bhp    5.0        NaN   1.75
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74
# ...       ...        ...    ...        ...    ...
# 7248  1598 CC  103.6 bhp    5.0        NaN    NaN
# 7249  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7250  1461 CC   63.1 bhp    5.0        NaN    NaN
# 7251  1197 CC  103.6 bhp    5.0        NaN    NaN
# 7252  2148 CC    170 bhp    5.0        NaN    NaN
#
# [7253 rows x 14 columns]

# %%
# Remove S.No. column from data
data = data.drop(['S.No.'], axis = 1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
# dtypes: float64(2), int64(2), object(9)
# memory usage: 736.8+ KB

# %% [markdown]
# # Feature Engineering

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price
# 0        NaN   1.75
# 1        NaN  12.50
# 2  8.61 Lakh   4.50
# 3        NaN   6.00
# 4        NaN  17.74

# %% [markdown]
# # It would be difficult to find the car’s age if it is in year format as the Age of the car is a contributing factor to Car Price.

# %%
from datetime import date
date.today().year
data['Car_Age']=date.today().year-data['Year']
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age
# 0        NaN   1.75       14
# 1        NaN  12.50        9
# 2  8.61 Lakh   4.50       13
# 3        NaN   6.00       12
# 4        NaN  17.74       11

# %% [markdown]
# # Since car names will not be great predictors of the price in our current data. But we can process this column to extract important information using brand and Model names. Let’s split the name and introduce new variables “Brand” and “Model”

# %%
data_name= data.Name.str.split()

# %%
data_name
# Out:
# 0                            [Maruti, Wagon, R, LXI, CNG]
# 1                 [Hyundai, Creta, 1.6, CRDi, SX, Option]
# 2                                        [Honda, Jazz, V]
# 3                                   [Maruti, Ertiga, VDI]
# 4                  [Audi, A4, New, 2.0, TDI, Multitronic]
#                               ...
# 7248               [Volkswagen, Vento, Diesel, Trendline]
# 7249                          [Volkswagen, Polo, GT, TSI]
# 7250                          [Nissan, Micra, Diesel, XV]
# 7251                          [Volkswagen, Polo, GT, TSI]
# 7252    [Mercedes-Benz, E-Class, 2009-2013, E, 220, CD...
# Name: Name, Length: 7253, dtype: object

# %%
data['Brand']=data.Name.str.split().str.get(0)

# %%
data
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 7248              89411    Diesel       Manual      First  20.54 kmpl
# 7249              59000    Petrol    Automatic      First  17.21 kmpl
# 7250              28000    Diesel       Manual      First  23.08 kmpl
# 7251              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price  Price  Car_Age          Brand
# 0      998 CC  58.16 bhp    5.0        NaN   1.75       14         Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50        9        Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50       13          Honda
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00       12         Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74       11           Audi
# ...       ...        ...    ...        ...    ...      ...            ...
# 7248  1598 CC  103.6 bhp    5.0        NaN    NaN       13     Volkswagen
# 7249  1197 CC  103.6 bhp    5.0        NaN    NaN        9     Volkswagen
# 7250  1461 CC   63.1 bhp    5.0        NaN    NaN       12         Nissan
# 7251  1197 CC  103.6 bhp    5.0        NaN    NaN       11     Volkswagen
# 7252  2148 CC    170 bhp    5.0        NaN    NaN       10  Mercedes-Benz
#
# [7253 rows x 15 columns]

# %%
data_model = data.Name.str.split().str.get(1) + data.Name.str.split().str.get(2)

# %%
data_model
# Out:
# 0                 WagonR
# 1               Creta1.6
# 2                  JazzV
# 3              ErtigaVDI
# 4                  A4New
#               ...
# 7248         VentoDiesel
# 7249              PoloGT
# 7250         MicraDiesel
# 7251              PoloGT
# 7252    E-Class2009-2013
# Name: Name, Length: 7253, dtype: object

# %%
data['Model'] = data.Name.str.split().str.get(1) +' '+ data.Name.str.split().str.get(2)
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age       Model
# 0        NaN   1.75       14     Wagon R
# 1        NaN  12.50        9   Creta 1.6
# 2  8.61 Lakh   4.50       13      Jazz V
# 3        NaN   6.00       12  Ertiga VDI
# 4        NaN  17.74       11      A4 New

# %%
data[['Name','Brand','Model']]
# Out:
#                                                    Name          Brand  \
# 0                                Maruti Wagon R LXI CNG         Maruti
# 1                      Hyundai Creta 1.6 CRDi SX Option        Hyundai
# 2                                          Honda Jazz V          Honda
# 3                                     Maruti Ertiga VDI         Maruti
# 4                       Audi A4 New 2.0 TDI Multitronic           Audi
# ...                                                 ...            ...
# 7248                  Volkswagen Vento Diesel Trendline     Volkswagen
# 7249                             Volkswagen Polo GT TSI     Volkswagen
# 7250                             Nissan Micra Diesel XV         Nissan
# 7251                             Volkswagen Polo GT TSI     Volkswagen
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...  Mercedes-Benz
#
#                   Model
# 0               Wagon R
# 1             Creta 1.6
# 2                Jazz V
# 3            Ertiga VDI
# 4                A4 New
# ...                 ...
# 7248       Vento Diesel
# 7249            Polo GT
# 7250       Micra Diesel
# 7251            Polo GT
# 7252  E-Class 2009-2013
#
# [7253 rows x 3 columns]

# %% [markdown]
# # Data Cleaning / Wrangling

# %%
data['Name'].head(50)
# Out:
# 0                               Maruti Wagon R LXI CNG
# 1                     Hyundai Creta 1.6 CRDi SX Option
# 2                                         Honda Jazz V
# 3                                    Maruti Ertiga VDI
# 4                      Audi A4 New 2.0 TDI Multitronic
# 5                      Hyundai EON LPG Era Plus Option
# 6                               Nissan Micra Diesel XV
# 7                    Toyota Innova Crysta 2.8 GX AT 8S
# 8                  Volkswagen Vento Diesel Comfortline
# 9                       Tata Indica Vista Quadrajet LS
# 10                                    Maruti Ciaz Zeta
# 11                         Honda City 1.5 V AT Sunroof
# 12                               Maruti Swift VDI BSIV
# 13                    Land Rover Range Rover 2.2L Pure
# 14                      Land Rover Freelander 2 TD4 SE
# 15                         Mitsubishi Pajero Sport 4X4
# 16                               Honda Amaze S i-Dtech
# 17                               Maruti Swift DDiS VDI
# 18                 Renault Duster 85PS Diesel RxL Plus
# 19    Mercedes-Benz New C-Class C 220 CDI BE Avantgare
# 20                                   BMW 3 Series 320d
# 21                       Maruti S Cross DDiS 200 Alpha
# 22                Audi A6 2011-2015 35 TFSI Technology
# 23                               Hyundai i20 1.2 Magna
# 24                 Volkswagen Vento Petrol Highline AT
# 25                        Honda City Corporate Edition
# 26                              Nissan Micra Diesel XV
# 27                       Maruti Alto K10 2010-2014 VXI
# 28                                 Honda WRV i-VTEC VX
# 29                 Toyota Innova 2.5 V Diesel 7-seater
# 30                Renault Duster 110PS Diesel RxZ Pack
# 31                              Toyota Corolla Altis G
# 32                       Mahindra Ssangyong Rexton RX7
# 33                                     Audi A6 2.7 TDI
# 34                       Volkswagen Vento 1.6 Highline
# 35                            Maruti Wagon R LXI BSIII
# 36                       Maruti Vitara Brezza ZDi Plus
# 37             Mahindra KUV 100 mFALCON G80 K6 5str AW
# 38                    Mercedes-Benz M-Class ML 350 CDI
# 39               Volkswagen Polo Diesel Trendline 1.2L
# 40                                     Maruti Alto LXi
# 41                                     Tata Nano LX SE
# 42           Mahindra KUV 100 mFALCON D75 K8 Dual Tone
# 43                      Hyundai i20 Magna Optional 1.2
# 44                    Hyundai Elantra 2.0 SX Option AT
# 45                           Toyota Corolla Altis G AT
# 46                                Hyundai Elantra CRDi
# 47                      Toyota Innova Crysta 2.7 GX MT
# 48                            Hyundai Xcent 1.1 CRDi S
# 49                               Mahindra Thar CRDe AC
# Name: Name, dtype: object

# %%
print(data.Brand.unique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra' 'Ford'
#  'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda' 'Mini' 'Fiat'
#  'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'ISUZU' 'Force' 'Bentley'
#  'Lamborghini' 'Hindustan' 'OpelCorsa']

# %%
print(data.Brand.nunique())
# Out:
# 33

# %%
searchfor = ['Isuzu' ,'ISUZU','Mini','Land']

# %%
searchfor
# Out:
# ['Isuzu', 'ISUZU', 'Mini', 'Land']

# %%
data[data.Brand.str.contains('|'.join(searchfor))].head()
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 13     Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 14     Diesel    Automatic     Second    0.0 kmpl  2179 CC     115 bhp    5.0
# 176    Diesel    Automatic     Second   16.6 kmpl  1998 CC     112 bhp    5.0
# 191    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 228    Petrol    Automatic      First  16.82 kmpl  1998 CC  189.08 bhp    4.0
#
#       New_Price  Price  Car_Age Brand               Model
# 13          NaN  27.00       10  Land         Rover Range
# 14          NaN  17.50       12  Land    Rover Freelander
# 176         NaN  23.00        7  Mini   Countryman Cooper
# 191         NaN  55.76        6  Land         Rover Range
# 228  44.28 Lakh  35.67        7  Mini  Cooper Convertible

# %%
data["Brand"].replace({"ISUZU": "Isuzu", "Mini": "Mini Cooper","Land":"Land Rover"}, inplace=True)

# %%
data[data.Brand.str.contains('|'.join(searchfor))].head()
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 13      Land Rover Range Rover 2.2L Pure       Delhi  2014              72000
# 14        Land Rover Freelander 2 TD4 SE        Pune  2012              85000
# 176             Mini Countryman Cooper D      Jaipur  2017               8525
# 191  Land Rover Range Rover 2.2L Dynamic  Coimbatore  2018              36091
# 228            Mini Cooper Convertible S       Kochi  2017              26327
#
#     Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  Seats  \
# 13     Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 14     Diesel    Automatic     Second    0.0 kmpl  2179 CC     115 bhp    5.0
# 176    Diesel    Automatic     Second   16.6 kmpl  1998 CC     112 bhp    5.0
# 191    Diesel    Automatic      First   12.7 kmpl  2179 CC   187.7 bhp    5.0
# 228    Petrol    Automatic      First  16.82 kmpl  1998 CC  189.08 bhp    4.0
#
#       New_Price  Price  Car_Age               Model        Brand
# 13          NaN  27.00       10         Rover Range   Land Rover
# 14          NaN  17.50       12    Rover Freelander   Land Rover
# 176         NaN  23.00        7   Countryman Cooper  Mini Cooper
# 191         NaN  55.76        6         Rover Range   Land Rover
# 228  44.28 Lakh  35.67        7  Cooper Convertible  Mini Cooper

# %%
print(data.Brand.nunique())
# Out:
# 32

# %%
print(data.Brand.unique())
# Out:
# ['Maruti' 'Hyundai' 'Honda' 'Audi' 'Nissan' 'Toyota' 'Volkswagen' 'Tata'
#  'Land Rover' 'Mitsubishi' 'Renault' 'Mercedes-Benz' 'BMW' 'Mahindra'
#  'Ford' 'Porsche' 'Datsun' 'Jaguar' 'Volvo' 'Chevrolet' 'Skoda'
#  'Mini Cooper' 'Fiat' 'Jeep' 'Smart' 'Ambassador' 'Isuzu' 'Force'
#  'Bentley' 'Lamborghini' 'Hindustan' 'OpelCorsa']

# %%
data
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 7248              89411    Diesel       Manual      First  20.54 kmpl
# 7249              59000    Petrol    Automatic      First  17.21 kmpl
# 7250              28000    Diesel       Manual      First  23.08 kmpl
# 7251              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price  Price  Car_Age          Brand  \
# 0      998 CC  58.16 bhp    5.0        NaN   1.75       14         Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50        9        Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50       13          Honda
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00       12         Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74       11           Audi
# ...       ...        ...    ...        ...    ...      ...            ...
# 7248  1598 CC  103.6 bhp    5.0        NaN    NaN       13     Volkswagen
# 7249  1197 CC  103.6 bhp    5.0        NaN    NaN        9     Volkswagen
# 7250  1461 CC   63.1 bhp    5.0        NaN    NaN       12         Nissan
# 7251  1197 CC  103.6 bhp    5.0        NaN    NaN       11     Volkswagen
# 7252  2148 CC    170 bhp    5.0        NaN    NaN       10  Mercedes-Benz
#
#                   Model
# 0               Wagon R
# 1             Creta 1.6
# 2                Jazz V
# 3            Ertiga VDI
# 4                A4 New
# ...                 ...
# 7248       Vento Diesel
# 7249            Polo GT
# 7250       Micra Diesel
# 7251            Polo GT
# 7252  E-Class 2009-2013
#
# [7253 rows x 16 columns]

# %% [markdown]
# # EDA
# EDA can be leveraged to check for outliers, patterns, and trends in the given data.
# EDA helps to find meaningful patterns in data.
# EDA provides in-depth insights into the data sets to solve our business problems.
# EDA gives a clue to impute missing values in the dataset

# %% [markdown]
# # Statistics Summary

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price      Car_Age
# count  7253.000000       7.253000e+03  7200.000000  6019.000000  7253.000000
# mean   2013.365366       5.869906e+04     5.279722     9.479468    10.634634
# std       3.254421       8.442772e+04     0.811660    11.187917     3.254421
# min    1996.000000       1.710000e+02     0.000000     0.440000     5.000000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000     8.000000
# 50%    2014.000000       5.341600e+04     5.000000     5.640000    10.000000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000    13.000000
# max    2019.000000       6.500000e+06    10.000000   160.000000    28.000000

# %%
data.describe().T
# Out:
#                     count          mean           std      min      25%  \
# Year               7253.0   2013.365366      3.254421  1996.00   2011.0
# Kilometers_Driven  7253.0  58699.063146  84427.720583   171.00  34000.0
# Seats              7200.0      5.279722      0.811660     0.00      5.0
# Price              6019.0      9.479468     11.187917     0.44      3.5
# Car_Age            7253.0     10.634634      3.254421     5.00      8.0
#
#                         50%       75%        max
# Year                2014.00   2016.00     2019.0
# Kilometers_Driven  53416.00  73000.00  6500000.0
# Seats                  5.00      5.00       10.0
# Price                  5.64      9.95      160.0
# Car_Age               10.00     13.00       28.0

# %% [markdown]
# # Years range from 1996- 2019 and has a high in a range which shows used cars contain both latest models and old model cars.

# %% [markdown]
# # On average of Kilometers-driven in Used cars are ~58k KM. The range shows a huge difference between min and max as max values show 650000 KM shows the evidence of an outlier. This record can be removed.

# %% [markdown]
# # The average number of seats in a car is 5. car seat is an important feature in price contribution.

# %% [markdown]
# # The max price of a used car is 160k which is quite weird, such a high price for used cars. There may be an outlier or data entry issue.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
#  13  Car_Age            7253 non-null   int64
#  14  Model              7252 non-null   object
#  15  Brand              7253 non-null   object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 906.8+ KB

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age    Brand       Model
# 0        NaN   1.75       14   Maruti     Wagon R
# 1        NaN  12.50        9  Hyundai   Creta 1.6
# 2  8.61 Lakh   4.50       13    Honda      Jazz V
# 3        NaN   6.00       12   Maruti  Ertiga VDI
# 4        NaN  17.74       11     Audi      A4 New

# %%
data.describe(include='all').T
# Out:
#                     count unique                     top  freq          mean  \
# Name                 7253   2041  Mahindra XUV500 W8 2WD    55           NaN
# Location             7253     11                  Mumbai   949           NaN
# Year               7253.0    NaN                     NaN   NaN   2013.365366
# Kilometers_Driven  7253.0    NaN                     NaN   NaN  58699.063146
# Fuel_Type            7253      5                  Diesel  3852           NaN
# Transmission         7253      2                  Manual  5204           NaN
# Owner_Type           7253      4                   First  5952           NaN
# Mileage              7251    450               17.0 kmpl   207           NaN
# Engine               7207    150                 1197 CC   732           NaN
# Power                7207    386                  74 bhp   280           NaN
# Seats              7200.0    NaN                     NaN   NaN      5.279722
# New_Price            1006    625              63.71 Lakh     6           NaN
# Price              6019.0    NaN                     NaN   NaN      9.479468
# Car_Age            7253.0    NaN                     NaN   NaN     10.634634
# Brand                7253     32                  Maruti  1444           NaN
# Model                7252    726             Swift Dzire   189           NaN
#
#                             std     min      25%      50%      75%        max
# Name                        NaN     NaN      NaN      NaN      NaN        NaN
# Location                    NaN     NaN      NaN      NaN      NaN        NaN
# Year                   3.254421  1996.0   2011.0   2014.0   2016.0     2019.0
# Kilometers_Driven  84427.720583   171.0  34000.0  53416.0  73000.0  6500000.0
# Fuel_Type                   NaN     NaN      NaN      NaN      NaN        NaN
# Transmission                NaN     NaN      NaN      NaN      NaN        NaN
# Owner_Type                  NaN     NaN      NaN      NaN      NaN        NaN
# Mileage                     NaN     NaN      NaN      NaN      NaN        NaN
# Engine                      NaN     NaN      NaN      NaN      NaN        NaN
# Power                       NaN     NaN      NaN      NaN      NaN        NaN
# Seats                   0.81166     0.0      5.0      5.0      5.0       10.0
# New_Price                   NaN     NaN      NaN      NaN      NaN        NaN
# Price                 11.187917    0.44      3.5     5.64     9.95      160.0
# Car_Age                3.254421     5.0      8.0     10.0     13.0       28.0
# Brand                       NaN     NaN      NaN      NaN      NaN        NaN
# Model                       NaN     NaN      NaN      NaN      NaN        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
#  13  Car_Age            7253 non-null   int64
#  14  Brand              7253 non-null   object
#  15  Model              7252 non-null   object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 906.8+ KB

# %%
data['Miles']=data.Mileage.str.split().str.get(0)

# %%
data
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 7248              89411    Diesel       Manual      First  20.54 kmpl
# 7249              59000    Petrol    Automatic      First  17.21 kmpl
# 7250              28000    Diesel       Manual      First  23.08 kmpl
# 7251              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price  Price  Car_Age          Brand  \
# 0      998 CC  58.16 bhp    5.0        NaN   1.75       14         Maruti
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50        9        Hyundai
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50       13          Honda
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00       12         Maruti
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74       11           Audi
# ...       ...        ...    ...        ...    ...      ...            ...
# 7248  1598 CC  103.6 bhp    5.0        NaN    NaN       13     Volkswagen
# 7249  1197 CC  103.6 bhp    5.0        NaN    NaN        9     Volkswagen
# 7250  1461 CC   63.1 bhp    5.0        NaN    NaN       12         Nissan
# 7251  1197 CC  103.6 bhp    5.0        NaN    NaN       11     Volkswagen
# 7252  2148 CC    170 bhp    5.0        NaN    NaN       10  Mercedes-Benz
#
#                   Model  Miles
# 0               Wagon R   26.6
# 1             Creta 1.6  19.67
# 2                Jazz V   18.2
# 3            Ertiga VDI  20.77
# 4                A4 New   15.2
# ...                 ...    ...
# 7248       Vento Diesel  20.54
# 7249            Polo GT  17.21
# 7250       Micra Diesel  23.08
# 7251            Polo GT   17.2
# 7252  E-Class 2009-2013   10.0
#
# [7253 rows x 17 columns]

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age    Brand       Model  Miles
# 0        NaN   1.75       14   Maruti     Wagon R   26.6
# 1        NaN  12.50        9  Hyundai   Creta 1.6  19.67
# 2  8.61 Lakh   4.50       13    Honda      Jazz V   18.2
# 3        NaN   6.00       12   Maruti  Ertiga VDI  20.77
# 4        NaN  17.74       11     Audi      A4 New   15.2

# %%
data['CC']=data.Engine.str.split().str.get(0)

# %%
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    New_Price  Price  Car_Age    Brand       Model  Miles    CC
# 0        NaN   1.75       14   Maruti     Wagon R   26.6   998
# 1        NaN  12.50        9  Hyundai   Creta 1.6  19.67  1582
# 2  8.61 Lakh   4.50       13    Honda      Jazz V   18.2  1199
# 3        NaN   6.00       12   Maruti  Ertiga VDI  20.77  1248
# 4        NaN  17.74       11     Audi      A4 New   15.2  1968

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
#  13  Car_Age            7253 non-null   int64
#  14  Model              7252 non-null   object
#  15  Brand              7253 non-null   object
#  16  Miles              7251 non-null   object
#  17  CC                 7207 non-null   object
# dtypes: float64(2), int64(3), object(13)
# memory usage: 1020.1+ KB

# %%
data['Miles'] = data['Miles'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Mileage            7251 non-null   object
#  8   Engine             7207 non-null   object
#  9   Power              7207 non-null   object
#  10  Seats              7200 non-null   float64
#  11  New_Price          1006 non-null   object
#  12  Price              6019 non-null   float64
#  13  Car_Age            7253 non-null   int64
#  14  Brand              7253 non-null   object
#  15  Model              7252 non-null   object
#  16  Miles              7251 non-null   float64
#  17  CC                 7207 non-null   object
# dtypes: float64(3), int64(3), object(12)
# memory usage: 1020.1+ KB

# %%
data['CC'] = data['CC'].astype(float)
data
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# 1                 41000    Diesel       Manual      First  19.67 kmpl
# 2                 46000    Petrol       Manual      First   18.2 kmpl
# 3                 87000    Diesel       Manual      First  20.77 kmpl
# 4                 40670    Diesel    Automatic     Second   15.2 kmpl
# ...                 ...       ...          ...        ...         ...
# 7248              89411    Diesel       Manual      First  20.54 kmpl
# 7249              59000    Petrol    Automatic      First  17.21 kmpl
# 7250              28000    Diesel       Manual      First  23.08 kmpl
# 7251              52262    Petrol    Automatic      Third   17.2 kmpl
# 7252              72443    Diesel    Automatic      First   10.0 kmpl
#
#        Engine      Power  Seats  New_Price  Price  Car_Age              Model  \
# 0      998 CC  58.16 bhp    5.0        NaN   1.75       14            Wagon R
# 1     1582 CC  126.2 bhp    5.0        NaN  12.50        9          Creta 1.6
# 2     1199 CC   88.7 bhp    5.0  8.61 Lakh   4.50       13             Jazz V
# 3     1248 CC  88.76 bhp    7.0        NaN   6.00       12         Ertiga VDI
# 4     1968 CC  140.8 bhp    5.0        NaN  17.74       11             A4 New
# ...       ...        ...    ...        ...    ...      ...                ...
# 7248  1598 CC  103.6 bhp    5.0        NaN    NaN       13       Vento Diesel
# 7249  1197 CC  103.6 bhp    5.0        NaN    NaN        9            Polo GT
# 7250  1461 CC   63.1 bhp    5.0        NaN    NaN       12       Micra Diesel
# 7251  1197 CC  103.6 bhp    5.0        NaN    NaN       11            Polo GT
# 7252  2148 CC    170 bhp    5.0        NaN    NaN       10  E-Class 2009-2013
#
#               Brand  Miles      CC
# 0            Maruti  26.60   998.0
# 1           Hyundai  19.67  1582.0
# 2             Honda  18.20  1199.0
# 3            Maruti  20.77  1248.0
# 4              Audi  15.20  1968.0
# ...             ...    ...     ...
# 7248     Volkswagen  20.54  1598.0
# 7249     Volkswagen  17.21  1197.0
# 7250         Nissan  23.08  1461.0
# 7251     Volkswagen  17.20  1197.0
# 7252  Mercedes-Benz  10.00  2148.0
#
# [7253 rows x 18 columns]

# %%
data.drop(['Mileage'], axis=1, inplace=True)

# %%
data.rename(columns= {'Miles' : 'Miles_kmpl'}, inplace=True)

# %%
data
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type   Engine      Power  \
# 0                 72000       CNG       Manual      First   998 CC  58.16 bhp
# 1                 41000    Diesel       Manual      First  1582 CC  126.2 bhp
# 2                 46000    Petrol       Manual      First  1199 CC   88.7 bhp
# 3                 87000    Diesel       Manual      First  1248 CC  88.76 bhp
# 4                 40670    Diesel    Automatic     Second  1968 CC  140.8 bhp
# ...                 ...       ...          ...        ...      ...        ...
# 7248              89411    Diesel       Manual      First  1598 CC  103.6 bhp
# 7249              59000    Petrol    Automatic      First  1197 CC  103.6 bhp
# 7250              28000    Diesel       Manual      First  1461 CC   63.1 bhp
# 7251              52262    Petrol    Automatic      Third  1197 CC  103.6 bhp
# 7252              72443    Diesel    Automatic      First  2148 CC    170 bhp
#
#       Seats  New_Price  Price  Car_Age          Brand              Model  \
# 0       5.0        NaN   1.75       14         Maruti            Wagon R
# 1       5.0        NaN  12.50        9        Hyundai          Creta 1.6
# 2       5.0  8.61 Lakh   4.50       13          Honda             Jazz V
# 3       7.0        NaN   6.00       12         Maruti         Ertiga VDI
# 4       5.0        NaN  17.74       11           Audi             A4 New
# ...     ...        ...    ...      ...            ...                ...
# 7248    5.0        NaN    NaN       13     Volkswagen       Vento Diesel
# 7249    5.0        NaN    NaN        9     Volkswagen            Polo GT
# 7250    5.0        NaN    NaN       12         Nissan       Micra Diesel
# 7251    5.0        NaN    NaN       11     Volkswagen            Polo GT
# 7252    5.0        NaN    NaN       10  Mercedes-Benz  E-Class 2009-2013
#
#       Miles_kmpl      CC
# 0          26.60   998.0
# 1          19.67  1582.0
# 2          18.20  1199.0
# 3          20.77  1248.0
# 4          15.20  1968.0
# ...          ...     ...
# 7248       20.54  1598.0
# 7249       17.21  1197.0
# 7250       23.08  1461.0
# 7251       17.20  1197.0
# 7252       10.00  2148.0
#
# [7253 rows x 17 columns]

# %%
data.rename(columns= {'CC' : 'Engine_CC'}, inplace=True)

# %%
data
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type   Engine      Power  \
# 0                 72000       CNG       Manual      First   998 CC  58.16 bhp
# 1                 41000    Diesel       Manual      First  1582 CC  126.2 bhp
# 2                 46000    Petrol       Manual      First  1199 CC   88.7 bhp
# 3                 87000    Diesel       Manual      First  1248 CC  88.76 bhp
# 4                 40670    Diesel    Automatic     Second  1968 CC  140.8 bhp
# ...                 ...       ...          ...        ...      ...        ...
# 7248              89411    Diesel       Manual      First  1598 CC  103.6 bhp
# 7249              59000    Petrol    Automatic      First  1197 CC  103.6 bhp
# 7250              28000    Diesel       Manual      First  1461 CC   63.1 bhp
# 7251              52262    Petrol    Automatic      Third  1197 CC  103.6 bhp
# 7252              72443    Diesel    Automatic      First  2148 CC    170 bhp
#
#       Seats  New_Price  Price  Car_Age          Brand              Model  \
# 0       5.0        NaN   1.75       14         Maruti            Wagon R
# 1       5.0        NaN  12.50        9        Hyundai          Creta 1.6
# 2       5.0  8.61 Lakh   4.50       13          Honda             Jazz V
# 3       7.0        NaN   6.00       12         Maruti         Ertiga VDI
# 4       5.0        NaN  17.74       11           Audi             A4 New
# ...     ...        ...    ...      ...            ...                ...
# 7248    5.0        NaN    NaN       13     Volkswagen       Vento Diesel
# 7249    5.0        NaN    NaN        9     Volkswagen            Polo GT
# 7250    5.0        NaN    NaN       12         Nissan       Micra Diesel
# 7251    5.0        NaN    NaN       11     Volkswagen            Polo GT
# 7252    5.0        NaN    NaN       10  Mercedes-Benz  E-Class 2009-2013
#
#       Miles_kmpl  Engine_CC
# 0          26.60      998.0
# 1          19.67     1582.0
# 2          18.20     1199.0
# 3          20.77     1248.0
# 4          15.20     1968.0
# ...          ...        ...
# 7248       20.54     1598.0
# 7249       17.21     1197.0
# 7250       23.08     1461.0
# 7251       17.20     1197.0
# 7252       10.00     2148.0
#
# [7253 rows x 17 columns]

# %%
data.drop(['Engine'], axis=1, inplace=True)

# %%
data
# Out:
#                                                    Name    Location  Year  \
# 0                                Maruti Wagon R LXI CNG      Mumbai  2010
# 1                      Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2                                          Honda Jazz V     Chennai  2011
# 3                                     Maruti Ertiga VDI     Chennai  2012
# 4                       Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...                                                 ...         ...   ...
# 7248                  Volkswagen Vento Diesel Trendline   Hyderabad  2011
# 7249                             Volkswagen Polo GT TSI      Mumbai  2015
# 7250                             Nissan Micra Diesel XV     Kolkata  2012
# 7251                             Volkswagen Polo GT TSI        Pune  2013
# 7252  Mercedes-Benz E-Class 2009-2013 E 220 CDI Avan...       Kochi  2014
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type      Power  Seats  \
# 0                 72000       CNG       Manual      First  58.16 bhp    5.0
# 1                 41000    Diesel       Manual      First  126.2 bhp    5.0
# 2                 46000    Petrol       Manual      First   88.7 bhp    5.0
# 3                 87000    Diesel       Manual      First  88.76 bhp    7.0
# 4                 40670    Diesel    Automatic     Second  140.8 bhp    5.0
# ...                 ...       ...          ...        ...        ...    ...
# 7248              89411    Diesel       Manual      First  103.6 bhp    5.0
# 7249              59000    Petrol    Automatic      First  103.6 bhp    5.0
# 7250              28000    Diesel       Manual      First   63.1 bhp    5.0
# 7251              52262    Petrol    Automatic      Third  103.6 bhp    5.0
# 7252              72443    Diesel    Automatic      First    170 bhp    5.0
#
#       New_Price  Price  Car_Age              Model          Brand  Miles_kmpl  \
# 0           NaN   1.75       14            Wagon R         Maruti       26.60
# 1           NaN  12.50        9          Creta 1.6        Hyundai       19.67
# 2     8.61 Lakh   4.50       13             Jazz V          Honda       18.20
# 3           NaN   6.00       12         Ertiga VDI         Maruti       20.77
# 4           NaN  17.74       11             A4 New           Audi       15.20
# ...         ...    ...      ...                ...            ...         ...
# 7248        NaN    NaN       13       Vento Diesel     Volkswagen       20.54
# 7249        NaN    NaN        9            Polo GT     Volkswagen       17.21
# 7250        NaN    NaN       12       Micra Diesel         Nissan       23.08
# 7251        NaN    NaN       11            Polo GT     Volkswagen       17.20
# 7252        NaN    NaN       10  E-Class 2009-2013  Mercedes-Benz       10.00
#
#       Engine_CC
# 0         998.0
# 1        1582.0
# 2        1199.0
# 3        1248.0
# 4        1968.0
# ...         ...
# 7248     1598.0
# 7249     1197.0
# 7250     1461.0
# 7251     1197.0
# 7252     2148.0
#
# [7253 rows x 16 columns]

# %% [markdown]
# # EDA Univariate Analysis
# Univariate analysis can be done for both Categorical and Numerical variables.
#
# Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc.
# Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               7253 non-null   object
#  1   Location           7253 non-null   object
#  2   Year               7253 non-null   int64
#  3   Kilometers_Driven  7253 non-null   int64
#  4   Fuel_Type          7253 non-null   object
#  5   Transmission       7253 non-null   object
#  6   Owner_Type         7253 non-null   object
#  7   Power              7207 non-null   object
#  8   Seats              7200 non-null   float64
#  9   New_Price          1006 non-null   object
#  10  Price              6019 non-null   float64
#  11  Car_Age            7253 non-null   int64
#  12  Model              7252 non-null   object
#  13  Brand              7253 non-null   object
#  14  Miles_kmpl         7251 non-null   float64
#  15  Engine_CC          7207 non-null   float64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 906.8+ KB

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price      Car_Age  \
# count  7253.000000       7.253000e+03  7200.000000  6019.000000  7253.000000
# mean   2013.365366       5.869906e+04     5.279722     9.479468    10.634634
# std       3.254421       8.442772e+04     0.811660    11.187917     3.254421
# min    1996.000000       1.710000e+02     0.000000     0.440000     5.000000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000     8.000000
# 50%    2014.000000       5.341600e+04     5.000000     5.640000    10.000000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000    13.000000
# max    2019.000000       6.500000e+06    10.000000   160.000000    28.000000
#
#         Miles_kmpl    Engine_CC
# count  7251.000000  7207.000000
# mean     18.141580  1616.573470
# std       4.562197   595.285137
# min       0.000000    72.000000
# 25%      15.170000  1198.000000
# 50%      18.160000  1493.000000
# 75%      21.100000  1968.000000
# max      33.540000  5998.000000

# %%
data.describe().T
# Out:
#                     count          mean           std      min       25%  \
# Year               7253.0   2013.365366      3.254421  1996.00   2011.00
# Kilometers_Driven  7253.0  58699.063146  84427.720583   171.00  34000.00
# Seats              7200.0      5.279722      0.811660     0.00      5.00
# Price              6019.0      9.479468     11.187917     0.44      3.50
# Car_Age            7253.0     10.634634      3.254421     5.00      8.00
# Miles_kmpl         7251.0     18.141580      4.562197     0.00     15.17
# Engine_CC          7207.0   1616.573470    595.285137    72.00   1198.00
#
#                         50%       75%         max
# Year                2014.00   2016.00     2019.00
# Kilometers_Driven  53416.00  73000.00  6500000.00
# Seats                  5.00      5.00       10.00
# Price                  5.64      9.95      160.00
# Car_Age               10.00     13.00       28.00
# Miles_kmpl            18.16     21.10       33.54
# Engine_CC           1493.00   1968.00     5998.00

# %%
cat_cols=data.select_dtypes(include=['object']).columns

# %%
cat_cols
# Out:
# Index(['Name', 'Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'Power',
#        'New_Price', 'Model', 'Brand'],
#       dtype='object')

# %%
num_cols = data.select_dtypes(include=np.number).columns.tolist()

# %%
num_cols
# Out:
# ['Year',
#  'Kilometers_Driven',
#  'Seats',
#  'Price',
#  'Car_Age',
#  'Miles_kmpl',
#  'Engine_CC']

# %% [raw]
# #Categorical variables can be visualized using a Count plot, Bar Chart, Pie Plot, etc

# %% [raw]
# # Numerical Variables can be visualized using Histogram, Box Plot, Density Plot, etc

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for col in num_cols:
    print(col)
    print('Skew :' , round(data[col].skew(),2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# Year
# Skew : -0.84
# Kilometers_Driven
# Skew : 61.58
# Seats
# Skew : 1.9
# Price
# Skew : 3.34
# Car_Age
# Skew : 0.84
# Miles_kmpl
# Skew : -0.44
# Engine_CC
# Skew : 1.41

# %% [raw]
# # Price and Kilometers Driven are right skewed for this data to be transformed, and all outliers will be handled during imputation

# %%
fig, axes = plt.subplots(3, 2, figsize = (18, 18))
fig.suptitle('Bar plot for all categorical variables in the dataset')
sns.countplot(ax = axes[0, 0], x = 'Fuel_Type', data = data, color = 'blue', order = data['Fuel_Type'].value_counts().index);
sns.countplot(ax = axes[0, 1], x = 'Transmission', data = data, color = 'blue', order = data['Transmission'].value_counts().index);
sns.countplot(ax = axes[1, 0], x = 'Owner_Type', data = data, color = 'blue', order = data['Owner_Type'].value_counts().index);
sns.countplot(ax = axes[1, 1], x = 'Location', data = data, color = 'blue', order = data['Location'].value_counts().index);
sns.countplot(ax = axes[2, 0], x = 'Brand', data = data, color = 'blue', order = data['Brand'].head(20).value_counts().index);
sns.countplot(ax = axes[2, 1], x = 'Model', data = data, color = 'blue', order = data['Model'].head(20).value_counts().index);
axes[1][1].tick_params(labelrotation=45);
axes[2][0].tick_params(labelrotation=90);
axes[2][1].tick_params(labelrotation=90);

# %% [markdown]
# # Mumbai has the highest number of cars available for purchase, followed by Hyderabad and Coimbatore
# # cars have fuel type as Diesel this shows diesel cars provide higher performance
# # Manual transmission cars are most liked
# # Maximum  used cars are owned by first user
# # Maruti has a highest number of cars to resale
# # Wangon R is mostly purchased

# %% [raw]
# # Price and Kilometer-Driven variables are highly skewed and on a larger scale. Let’s do log transformation.

# %%
# Function for log transformation of the column
def log_transform(data,col):
    for colname in col:
        if (data[colname] == 1.0).all():
            data[colname + '_log'] = np.log(data[colname]+1)
        else:
            data[colname + '_log'] = np.log(data[colname])
    data.info()
# calling function
log_transform(data,['Kilometers_Driven','Price'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   7253 non-null   object
#  1   Location               7253 non-null   object
#  2   Year                   7253 non-null   int64
#  3   Kilometers_Driven      7253 non-null   int64
#  4   Fuel_Type              7253 non-null   object
#  5   Transmission           7253 non-null   object
#  6   Owner_Type             7253 non-null   object
#  7   Power                  7207 non-null   object
#  8   Seats                  7200 non-null   float64
#  9   New_Price              1006 non-null   object
#  10  Price                  6019 non-null   float64
#  11  Car_Age                7253 non-null   int64
#  12  Model                  7252 non-null   object
#  13  Brand                  7253 non-null   object
#  14  Miles_kmpl             7251 non-null   float64
#  15  Engine_CC              7207 non-null   float64
#  16  Kilometers_Driven_log  7253 non-null   float64
#  17  Price_log              6019 non-null   float64
# dtypes: float64(6), int64(3), object(9)
# memory usage: 1020.1+ KB

# %%
#Log transformation of the feature 'Kilometers_Driven'
sns.distplot(data["Kilometers_Driven_log"], axlabel="Kilometers_Driven_log");
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19556\512774691.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Kilometers_Driven_log"], axlabel="Kilometers_Driven_log");

# %%
#Log transformation of the feature 'Kilometers_Driven'
sns.distplot(data["Kilometers_Driven"], axlabel="Kilometers_Driven");
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19556\3328867306.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Kilometers_Driven"], axlabel="Kilometers_Driven");

# %%
#Log transformation of the feature 'Kilometers_Driven'
sns.distplot(data["Price"], axlabel="Price");
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19556\2712398919.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Price"], axlabel="Price");

# %%
#Log transformation of the feature 'Kilometers_Driven'
sns.distplot(data["Price_log"], axlabel="Price_log");
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19556\44078415.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Price_log"], axlabel="Price_log");

# %%
data['Price']
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 7248      NaN
# 7249      NaN
# 7250      NaN
# 7251      NaN
# 7252      NaN
# Name: Price, Length: 7253, dtype: float64

# %%
data['Price_log']
# Out:
# 0       0.559616
# 1       2.525729
# 2       1.504077
# 3       1.791759
# 4       2.875822
#           ...
# 7248         NaN
# 7249         NaN
# 7250         NaN
# 7251         NaN
# 7252         NaN
# Name: Price_log, Length: 7253, dtype: float64

# %% [markdown]
# # EDA Bivariate Analysis

# %% [raw]
# #Bivariate Analysis helps to understand how variables are related to each other and the relationship between dependent and independent variables present in the dataset.

# %% [raw]
# #For Numerical variables, Pair plots and Scatter plots are widely been used to do Bivariate Analysis.

# %% [raw]
# # A Stacked bar chart can be used for categorical variables if the output variable is a classifier. Bar plots can be used if the output variable is continuous

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data=data.drop(['Kilometers_Driven','Price'],axis=1))
plt.show()

# %% [raw]
# #Pair Plot provides below insights:
#
# #The variable Year has a positive correlation with price and mileage
# #A year has a Negative correlation with kilometers-Driven
# #Mileage is negatively correlated with Power
# #As power increases, mileage decreases
# #Car with recent make is higher at prices. As the age of the car increases price decreases
# # Engine and Power increase, and the price of the car increases

# %% [raw]
# #A bar plot can be used to show the relationship between Categorical variables and continuous variables

# %%
fig, axarr = plt.subplots(4, 2, figsize=(12, 18))
data.groupby('Location')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][0], fontsize=12)
axarr[0][0].set_title("Location Vs Price", fontsize=18)
data.groupby('Transmission')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[0][1], fontsize=12)
axarr[0][1].set_title("Transmission Vs Price", fontsize=18)
data.groupby('Fuel_Type')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][0], fontsize=12)
axarr[1][0].set_title("Fuel_Type Vs Price", fontsize=18)
data.groupby('Owner_Type')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[1][1], fontsize=12)
axarr[1][1].set_title("Owner_Type Vs Price", fontsize=18)
data.groupby('Brand')['Price_log'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][0], fontsize=12)
axarr[2][0].set_title("Brand Vs Price", fontsize=18)
data.groupby('Model')['Price_log'].mean().sort_values(ascending=False).head(10).plot.bar(ax=axarr[2][1], fontsize=12)
axarr[2][1].set_title("Model Vs Price", fontsize=18)
data.groupby('Seats')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][0], fontsize=12)
axarr[3][0].set_title("Seats Vs Price", fontsize=18)
data.groupby('Car_Age')['Price_log'].mean().sort_values(ascending=False).plot.bar(ax=axarr[3][1], fontsize=12)
axarr[3][1].set_title("Car_Age Vs Price", fontsize=18)
plt.subplots_adjust(hspace=1.0)
plt.subplots_adjust(wspace=.5)
sns.despine()

# %% [markdown]
# # Observations
# #
# The price of cars is high in Coimbatore and less price in Kolkata and Jaipur#
# Automatic cars have more price than manual cars# .
# Diesel and Electric cars have almost the same price, which is maximum, and LPG cars have the lowest pri# ce
# First-owner cars are higher in price, followed by a sec# ond
# The third owner’s price is lesser than the Fourth and
# # Lamborghini brand is the highest in price
# #
# Gallardocoupe Model is the highest in price#
# 2 Seater has the highest price followed by 7 Seate# r
# The latest model cars are high in prceabove

# %% [markdown]
# # EDA Multivariate Analysis

# %%
num_cols
# Out:
# ['Year',
#  'Kilometers_Driven',
#  'Seats',
#  'Price',
#  'Car_Age',
#  'Miles_kmpl',
#  'Engine_CC']

# %%
plt.figure(figsize=(12, 7))
sns.heatmap(data[num_cols].corr(), annot = True, vmin = -1, vmax = 1)
plt.show()

# %% [markdown]
# # The engine has a strong positive correlation to Power 0.86
# #
# Price has a positive correlation to Engine 0.69 as well Power 0.77#
# Mileage has correlated to Engine, Power, and Price negativel# y
# Price is moderately positive in correlation to yea# r.
# Kilometer driven has a negative correlation to year not much impact on the pr# ice
# Car age has a negative correlation with P# rice
# car Age is positively correlated to Kilometers-Driven as the Age of the car increases; then the kilometer will also increase of car has a negative correlation with Mileage this makes sense

# %% [markdown]
# # Impute Missing values

# %% [markdown]
# In our dataset, we have found there are missing values for many columns like Mileage, Power, and Seats.
#
# We observed earlier some observations have zero Mileage. This looks like a data entry issue. We could fix this by filling null values with zero and then the mean value of Mileage since Mean and Median values are nearly the same for this variable chosen Mean to impute the values.

# %%
data.loc[data["Miles_kmpl"]==0.0,'Miles_kmpl']=np.nan
data.Miles_kmpl.isnull().sum()
# Out:
# 83

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   7253 non-null   object
#  1   Location               7253 non-null   object
#  2   Year                   7253 non-null   int64
#  3   Kilometers_Driven      7253 non-null   int64
#  4   Fuel_Type              7253 non-null   object
#  5   Transmission           7253 non-null   object
#  6   Owner_Type             7253 non-null   object
#  7   Power                  7207 non-null   object
#  8   Seats                  7200 non-null   float64
#  9   New_Price              1006 non-null   object
#  10  Price                  6019 non-null   float64
#  11  Car_Age                7253 non-null   int64
#  12  Model                  7252 non-null   object
#  13  Brand                  7253 non-null   object
#  14  Miles_kmpl             7251 non-null   float64
#  15  Engine_CC              7207 non-null   float64
#  16  Kilometers_Driven_log  7253 non-null   float64
#  17  Price_log              6019 non-null   float64
# dtypes: float64(6), int64(3), object(9)
# memory usage: 1020.1+ KB

# %%
data['Miles_kmpl']
# Out:
# <bound method Series.unique of 0       26.60
# 1       19.67
# 2       18.20
# 3       20.77
# 4       15.20
#         ...
# 7248    20.54
# 7249    17.21
# 7250    23.08
# 7251    17.20
# 7252    10.00
# Name: Miles_kmpl, Length: 7253, dtype: float64>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   7253 non-null   object
#  1   Location               7253 non-null   object
#  2   Year                   7253 non-null   int64
#  3   Kilometers_Driven      7253 non-null   int64
#  4   Fuel_Type              7253 non-null   object
#  5   Transmission           7253 non-null   object
#  6   Owner_Type             7253 non-null   object
#  7   Power                  7207 non-null   object
#  8   Seats                  7200 non-null   float64
#  9   New_Price              1006 non-null   object
#  10  Price                  6019 non-null   float64
#  11  Car_Age                7253 non-null   int64
#  12  Model                  7252 non-null   object
#  13  Brand                  7253 non-null   object
#  14  Miles_kmpl             7251 non-null   float64
#  15  Engine_CC              7207 non-null   float64
#  16  Kilometers_Driven_log  7253 non-null   float64
#  17  Price_log              6019 non-null   float64
#  18  Mileage                0 non-null      float64
# dtypes: float64(7), int64(3), object(9)
# memory usage: 1.1+ MB
